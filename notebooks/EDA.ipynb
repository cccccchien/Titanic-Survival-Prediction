# %% [markdown]
# <a href="https://colab.research.google.com/github/cccccchien/Titanic-Survival-Prediction/blob/main/notebooks/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 從一個常用的 GitHub 來源抓取 Titanic 資料
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

# 畫出性別與生存關係長條圖 (對應你手稿中的 EDA)
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Sex', hue='Survived', palette='viridis')
plt.title('Titanic Survival by Sex (EDA)')
plt.show()
